# %%
import pandas as pd

xg_data = pd.read_csv('~/Desktop/python/python/xG/epl_xg.csv')
xg_data['GD'] = xg_data['G'] - xg_data['GA']
xg_data['xGD'] = xg_data['xG'] - xg_data['xGA']
xg_data['NPxGD'] = xg_data['NPxG'] - xg_data['NPxGA']
xg_data
# Out:
#                        Team  Games   G  GA     xG    xGA   NPxG  NPxGA  GD  \
# 0                   Arsenal      8  19  10  10.41  10.95  10.41  10.95   9
# 1               Bournemouth      8  16  12  16.08   9.25  12.27   7.73   4
# 2                  Brighton      8   9  13   9.49  14.71   6.44  12.43  -4
# 3                   Burnley      8  10  12   7.69  14.11   7.69  13.35  -2
# 4                   Cardiff      8   4  17   7.44  13.68   7.44  11.40 -13
# 5                   Chelsea      8  18   5  15.72   8.59  13.44   8.59  13
# 6            Crystal Palace      8   5   9   7.02  11.56   7.02   9.28  -4
# 7                   Everton      8  13  12   9.52   9.76   8.76   9.00   1
# 8                    Fulham      8   9  21   9.41  18.00   9.41  15.71 -12
# 9              Huddersfield      8   4  17   4.75  13.26   4.75  11.74 -13
# 10                Leicester      8  14  12   9.14   8.58   7.62   7.05   2
# 11                Liverpool      8  15   3  16.66   5.90  15.90   5.14  12
# 12          Manchester City      8  21   3  22.49   4.00  21.72   4.00  18
# 13        Manchester United      8  13  14  12.83  10.98  10.54  10.22  -1
# 14                Newcastle      8   6  13   5.98  12.86   5.22  11.34  -7
# 15              Southampton      8   6  14  10.61  14.02   9.09  13.26  -8
# 16                Tottenham      8  15   7  14.79   9.66  13.27   9.66   8
# 17                  Watford      8  11  12  10.55  11.01  10.55  10.25  -1
# 18                 West Ham      8   8  13   8.73  13.32   7.97  13.32  -5
# 19  Wolverhampton Wanderers      8   9   6  11.06   6.15  11.06   6.15   3
#
#       xGD  NPxGD
# 0   -0.54  -0.54
# 1    6.83   4.54
# 2   -5.22  -5.99
# 3   -6.42  -5.66
# 4   -6.24  -3.96
# 5    7.13   4.85
# 6   -4.54  -2.26
# 7   -0.24  -0.24
# 8   -8.59  -6.30
# 9   -8.51  -6.99
# 10   0.56   0.57
# 11  10.76  10.76
# 12  18.49  17.72
# 13   1.85   0.32
# 14  -6.88  -6.12
# 15  -3.41  -4.17
# 16   5.13   3.61
# 17  -0.46   0.30
# 18  -4.59  -5.35
# 19   4.91   4.91

# %%
cols = ['G', 'GA', 'xG', 'xGA', 'NPxG', 'NPxGA', 'GD', 'xGD', 'NPxGD']
for col in cols:
    xg_data['%s_pg' % col] = xg_data[col] / xg_data['Games']

xg_data
# Out:
#                        Team  Games   G  GA     xG    xGA   NPxG  NPxGA  GD  \
# 0                   Arsenal      8  19  10  10.41  10.95  10.41  10.95   9
# 1               Bournemouth      8  16  12  16.08   9.25  12.27   7.73   4
# 2                  Brighton      8   9  13   9.49  14.71   6.44  12.43  -4
# 3                   Burnley      8  10  12   7.69  14.11   7.69  13.35  -2
# 4                   Cardiff      8   4  17   7.44  13.68   7.44  11.40 -13
# 5                   Chelsea      8  18   5  15.72   8.59  13.44   8.59  13
# 6            Crystal Palace      8   5   9   7.02  11.56   7.02   9.28  -4
# 7                   Everton      8  13  12   9.52   9.76   8.76   9.00   1
# 8                    Fulham      8   9  21   9.41  18.00   9.41  15.71 -12
# 9              Huddersfield      8   4  17   4.75  13.26   4.75  11.74 -13
# 10                Leicester      8  14  12   9.14   8.58   7.62   7.05   2
# 11                Liverpool      8  15   3  16.66   5.90  15.90   5.14  12
# 12          Manchester City      8  21   3  22.49   4.00  21.72   4.00  18
# 13        Manchester United      8  13  14  12.83  10.98  10.54  10.22  -1
# 14                Newcastle      8   6  13   5.98  12.86   5.22  11.34  -7
# 15              Southampton      8   6  14  10.61  14.02   9.09  13.26  -8
# 16                Tottenham      8  15   7  14.79   9.66  13.27   9.66   8
# 17                  Watford      8  11  12  10.55  11.01  10.55  10.25  -1
# 18                 West Ham      8   8  13   8.73  13.32   7.97  13.32  -5
# 19  Wolverhampton Wanderers      8   9   6  11.06   6.15  11.06   6.15   3
#
#       xGD  NPxGD   G_pg  GA_pg    xG_pg   xGA_pg  NPxG_pg  NPxGA_pg  GD_pg  \
# 0   -0.54  -0.54  2.375  1.250  1.30125  1.36875  1.30125   1.36875  1.125
# 1    6.83   4.54  2.000  1.500  2.01000  1.15625  1.53375   0.96625  0.500
# 2   -5.22  -5.99  1.125  1.625  1.18625  1.83875  0.80500   1.55375 -0.500
# 3   -6.42  -5.66  1.250  1.500  0.96125  1.76375  0.96125   1.66875 -0.250
# 4   -6.24  -3.96  0.500  2.125  0.93000  1.71000  0.93000   1.42500 -1.625
# 5    7.13   4.85  2.250  0.625  1.96500  1.07375  1.68000   1.07375  1.625
# 6   -4.54  -2.26  0.625  1.125  0.87750  1.44500  0.87750   1.16000 -0.500
# 7   -0.24  -0.24  1.625  1.500  1.19000  1.22000  1.09500   1.12500  0.125
# 8   -8.59  -6.30  1.125  2.625  1.17625  2.25000  1.17625   1.96375 -1.500
# 9   -8.51  -6.99  0.500  2.125  0.59375  1.65750  0.59375   1.46750 -1.625
# 10   0.56   0.57  1.750  1.500  1.14250  1.07250  0.95250   0.88125  0.250
# 11  10.76  10.76  1.875  0.375  2.08250  0.73750  1.98750   0.64250  1.500
# 12  18.49  17.72  2.625  0.375  2.81125  0.50000  2.71500   0.50000  2.250
# 13   1.85   0.32  1.625  1.750  1.60375  1.37250  1.31750   1.27750 -0.125
# 14  -6.88  -6.12  0.750  1.625  0.74750  1.60750  0.65250   1.41750 -0.875
# 15  -3.41  -4.17  0.750  1.750  1.32625  1.75250  1.13625   1.65750 -1.000
# 16   5.13   3.61  1.875  0.875  1.84875  1.20750  1.65875   1.20750  1.000
# 17  -0.46   0.30  1.375  1.500  1.31875  1.37625  1.31875   1.28125 -0.125
# 18  -4.59  -5.35  1.000  1.625  1.09125  1.66500  0.99625   1.66500 -0.625
# 19   4.91   4.91  1.125  0.750  1.38250  0.76875  1.38250   0.76875  0.375
#
#      xGD_pg  NPxGD_pg
# 0  -0.06750  -0.06750
# 1   0.85375   0.56750
# 2  -0.65250  -0.74875
# 3  -0.80250  -0.70750
# 4  -0.78000  -0.49500
# 5   0.89125   0.60625
# 6  -0.56750  -0.28250
# 7  -0.03000  -0.03000
# 8  -1.07375  -0.78750
# 9  -1.06375  -0.87375
# 10  0.07000   0.07125
# 11  1.34500   1.34500
# 12  2.31125   2.21500
# 13  0.23125   0.04000
# 14 -0.86000  -0.76500
# 15 -0.42625  -0.52125
# 16  0.64125   0.45125
# 17 -0.05750   0.03750
# 18 -0.57375  -0.66875
# 19  0.61375   0.61375

# %%
fixtures = pd.read_csv('~/Desktop/python/python/xG/epl_fixtures.csv')
fixtures2 = pd.read_csv('~/Desktop/python/python/xG/epl_fixtures.csv')
fixtures
# Out:
#          Home_Team          Away_Team
# 0          Chelsea  Manchester United
# 1      Bournemouth        Southampton
# 2          Cardiff             Fulham
# 3  Manchester City            Burnley
# 4        Newcastle           Brighton
# 5         West Ham          Tottenham
# 6           Wolves            Watford
# 7     Huddersfield          Liverpool
# 8          Everton     Crystal Palace
# 9          Arsenal          Leicester

# %%
xg_data_pg = xg_data[['Team', 'xG_pg', 'xGA_pg']]
fixtures = pd.merge(fixtures, xg_data_pg, left_on='Home_Team', right_on='Team')
fixtures
# Out:
#          Home_Team          Away_Team  xG_pg_x  xGA_pg_x  xG_pg_y  xGA_pg_y  \
# 0          Chelsea  Manchester United  1.96500   1.07375  1.60375   1.37250
# 1      Bournemouth        Southampton  2.01000   1.15625  1.32625   1.75250
# 2          Cardiff             Fulham  0.93000   1.71000  1.17625   2.25000
# 3  Manchester City            Burnley  2.81125   0.50000  0.96125   1.76375
# 4        Newcastle           Brighton  0.74750   1.60750  1.18625   1.83875
# 5         West Ham          Tottenham  1.09125   1.66500  1.84875   1.20750
# 6     Huddersfield          Liverpool  0.59375   1.65750  2.08250   0.73750
# 7          Everton     Crystal Palace  1.19000   1.22000  0.87750   1.44500
# 8          Arsenal          Leicester  1.30125   1.36875  1.14250   1.07250
#
#               Team_x  xG_pg_x  xGA_pg_x           Team_y  xG_pg_y  xGA_pg_y
# 0  Manchester United  1.60375   1.37250          Chelsea  1.96500   1.07375
# 1        Southampton  1.32625   1.75250      Bournemouth  2.01000   1.15625
# 2             Fulham  1.17625   2.25000          Cardiff  0.93000   1.71000
# 3            Burnley  0.96125   1.76375  Manchester City  2.81125   0.50000
# 4           Brighton  1.18625   1.83875        Newcastle  0.74750   1.60750
# 5          Tottenham  1.84875   1.20750         West Ham  1.09125   1.66500
# 6          Liverpool  2.08250   0.73750     Huddersfield  0.59375   1.65750
# 7     Crystal Palace  0.87750   1.44500          Everton  1.19000   1.22000
# 8          Leicester  1.14250   1.07250          Arsenal  1.30125   1.36875

# %%
fixtures = pd.merge(fixtures, xg_data_pg, left_on='Away_Team', right_on='Team')
fixtures
# Out:
#          Home_Team          Away_Team  xG_pg_x  xGA_pg_x  xG_pg_y  xGA_pg_y  \
# 0          Chelsea  Manchester United  1.96500   1.07375  1.60375   1.37250
# 1      Bournemouth        Southampton  2.01000   1.15625  1.32625   1.75250
# 2          Cardiff             Fulham  0.93000   1.71000  1.17625   2.25000
# 3  Manchester City            Burnley  2.81125   0.50000  0.96125   1.76375
# 4        Newcastle           Brighton  0.74750   1.60750  1.18625   1.83875
# 5         West Ham          Tottenham  1.09125   1.66500  1.84875   1.20750
# 6     Huddersfield          Liverpool  0.59375   1.65750  2.08250   0.73750
# 7          Everton     Crystal Palace  1.19000   1.22000  0.87750   1.44500
# 8          Arsenal          Leicester  1.30125   1.36875  1.14250   1.07250
#
#               Team_x  xG_pg_x  xGA_pg_x           Team_y  xG_pg_y  xGA_pg_y  \
# 0  Manchester United  1.60375   1.37250          Chelsea  1.96500   1.07375
# 1        Southampton  1.32625   1.75250      Bournemouth  2.01000   1.15625
# 2             Fulham  1.17625   2.25000          Cardiff  0.93000   1.71000
# 3            Burnley  0.96125   1.76375  Manchester City  2.81125   0.50000
# 4           Brighton  1.18625   1.83875        Newcastle  0.74750   1.60750
# 5          Tottenham  1.84875   1.20750         West Ham  1.09125   1.66500
# 6          Liverpool  2.08250   0.73750     Huddersfield  0.59375   1.65750
# 7     Crystal Palace  0.87750   1.44500          Everton  1.19000   1.22000
# 8          Leicester  1.14250   1.07250          Arsenal  1.30125   1.36875
#
#                 Team    xG_pg   xGA_pg
# 0  Manchester United  1.60375  1.37250
# 1        Southampton  1.32625  1.75250
# 2             Fulham  1.17625  2.25000
# 3            Burnley  0.96125  1.76375
# 4           Brighton  1.18625  1.83875
# 5          Tottenham  1.84875  1.20750
# 6          Liverpool  2.08250  0.73750
# 7     Crystal Palace  0.87750  1.44500
# 8          Leicester  1.14250  1.07250

# %%
fixtures = fixtures.drop(['Team_x', 'Team_y'], axis=1)
fixtures
# Out:
#          Home_Team          Away_Team  xG_pg_x  xGA_pg_x  xG_pg_y  xGA_pg_y  \
# 0          Chelsea  Manchester United  1.96500   1.07375  1.60375   1.37250
# 1      Bournemouth        Southampton  2.01000   1.15625  1.32625   1.75250
# 2          Cardiff             Fulham  0.93000   1.71000  1.17625   2.25000
# 3  Manchester City            Burnley  2.81125   0.50000  0.96125   1.76375
# 4        Newcastle           Brighton  0.74750   1.60750  1.18625   1.83875
# 5         West Ham          Tottenham  1.09125   1.66500  1.84875   1.20750
# 6     Huddersfield          Liverpool  0.59375   1.65750  2.08250   0.73750
# 7          Everton     Crystal Palace  1.19000   1.22000  0.87750   1.44500
# 8          Arsenal          Leicester  1.30125   1.36875  1.14250   1.07250
#
#    xG_pg_x  xGA_pg_x  xG_pg_y  xGA_pg_y               Team    xG_pg   xGA_pg
# 0  1.60375   1.37250  1.96500   1.07375  Manchester United  1.60375  1.37250
# 1  1.32625   1.75250  2.01000   1.15625        Southampton  1.32625  1.75250
# 2  1.17625   2.25000  0.93000   1.71000             Fulham  1.17625  2.25000
# 3  0.96125   1.76375  2.81125   0.50000            Burnley  0.96125  1.76375
# 4  1.18625   1.83875  0.74750   1.60750           Brighton  1.18625  1.83875
# 5  1.84875   1.20750  1.09125   1.66500          Tottenham  1.84875  1.20750
# 6  2.08250   0.73750  0.59375   1.65750          Liverpool  2.08250  0.73750
# 7  0.87750   1.44500  1.19000   1.22000     Crystal Palace  0.87750  1.44500
# 8  1.14250   1.07250  1.30125   1.36875          Leicester  1.14250  1.07250

# %%
fixtures = fixtures.rename(columns={'xG_pg_x': 'xG_pg_home_team', 'xGA_pg_x': 'xGA_pg_home_team', 'xG_pg_y': 'xG_pg_away_team', 'xGA_pg_y': 'xGA_pg_away_team'})
fixtures = fixtures.drop(['Team'], axis=1)
fixtures
# Out:
#          Home_Team          Away_Team  xG_pg_home_team  xGA_pg_home_team  \
# 0          Chelsea  Manchester United          1.96500           1.07375
# 1      Bournemouth        Southampton          2.01000           1.15625
# 2          Cardiff             Fulham          0.93000           1.71000
# 3  Manchester City            Burnley          2.81125           0.50000
# 4        Newcastle           Brighton          0.74750           1.60750
# 5         West Ham          Tottenham          1.09125           1.66500
# 6     Huddersfield          Liverpool          0.59375           1.65750
# 7          Everton     Crystal Palace          1.19000           1.22000
# 8          Arsenal          Leicester          1.30125           1.36875
#
#    xG_pg_away_team  xGA_pg_away_team  xG_pg_home_team  xGA_pg_home_team  \
# 0          1.60375           1.37250          1.60375           1.37250
# 1          1.32625           1.75250          1.32625           1.75250
# 2          1.17625           2.25000          1.17625           2.25000
# 3          0.96125           1.76375          0.96125           1.76375
# 4          1.18625           1.83875          1.18625           1.83875
# 5          1.84875           1.20750          1.84875           1.20750
# 6          2.08250           0.73750          2.08250           0.73750
# 7          0.87750           1.44500          0.87750           1.44500
# 8          1.14250           1.07250          1.14250           1.07250
#
#    xG_pg_away_team  xGA_pg_away_team    xG_pg   xGA_pg
# 0          1.96500           1.07375  1.60375  1.37250
# 1          2.01000           1.15625  1.32625  1.75250
# 2          0.93000           1.71000  1.17625  2.25000
# 3          2.81125           0.50000  0.96125  1.76375
# 4          0.74750           1.60750  1.18625  1.83875
# 5          1.09125           1.66500  1.84875  1.20750
# 6          0.59375           1.65750  2.08250  0.73750
# 7          1.19000           1.22000  0.87750  1.44500
# 8          1.30125           1.36875  1.14250  1.07250

# %%
xg_data_pg.set_index('Team', inplace=True)
xg_data_pg
# Out:
#                            xG_pg   xGA_pg
# Team
# Arsenal                  1.30125  1.36875
# Bournemouth              2.01000  1.15625
# Brighton                 1.18625  1.83875
# Burnley                  0.96125  1.76375
# Cardiff                  0.93000  1.71000
# Chelsea                  1.96500  1.07375
# Crystal Palace           0.87750  1.44500
# Everton                  1.19000  1.22000
# Fulham                   1.17625  2.25000
# Huddersfield             0.59375  1.65750
# Leicester                1.14250  1.07250
# Liverpool                2.08250  0.73750
# Manchester City          2.81125  0.50000
# Manchester United        1.60375  1.37250
# Newcastle                0.74750  1.60750
# Southampton              1.32625  1.75250
# Tottenham                1.84875  1.20750
# Watford                  1.31875  1.37625
# West Ham                 1.09125  1.66500
# Wolverhampton Wanderers  1.38250  0.76875

# %%
fixtures2['xG_pg_home_team'] = fixtures2['Home_Team'].map(xg_data_pg['xG_pg'])
fixtures2['xGA_pg_home_team'] = fixtures2['Home_Team'].map(xg_data_pg['xGA_pg'])
fixtures2['xG_pg_away_team'] = fixtures2['Away_Team'].map(xg_data_pg['xG_pg'])
fixtures2['xGA_pg_away_team'] = fixtures2['Away_Team'].map(xg_data_pg['xGA_pg'])
fixtures2
# Out:
#          Home_Team          Away_Team  xG_pg_home_team  xGA_pg_home_team  \
# 0          Chelsea  Manchester United          1.96500           1.07375
# 1      Bournemouth        Southampton          2.01000           1.15625
# 2          Cardiff             Fulham          0.93000           1.71000
# 3  Manchester City            Burnley          2.81125           0.50000
# 4        Newcastle           Brighton          0.74750           1.60750
# 5         West Ham          Tottenham          1.09125           1.66500
# 6           Wolves            Watford              NaN               NaN
# 7     Huddersfield          Liverpool          0.59375           1.65750
# 8          Everton     Crystal Palace          1.19000           1.22000
# 9          Arsenal          Leicester          1.30125           1.36875
#
#    xG_pg_away_team  xGA_pg_away_team
# 0          1.60375           1.37250
# 1          1.32625           1.75250
# 2          1.17625           2.25000
# 3          0.96125           1.76375
# 4          1.18625           1.83875
# 5          1.84875           1.20750
# 6          1.31875           1.37625
# 7          2.08250           0.73750
# 8          0.87750           1.44500
# 9          1.14250           1.07250

# %%
xG_avg = xg_data_pg['xG_pg'].mean()
matchups = fixtures2.copy()
matchups['xG_adjusted_home_team'] = (matchups['xG_pg_home_team'] * matchups['xGA_pg_away_team']) / xG_avg
matchups['xG_adjusted_away_team'] = (matchups['xG_pg_away_team'] * matchups['xGA_pg_home_team']) / xG_avg
matchups
# Out:
#          Home_Team          Away_Team  xG_pg_home_team  xGA_pg_home_team  \
# 0          Chelsea  Manchester United          1.96500           1.07375
# 1      Bournemouth        Southampton          2.01000           1.15625
# 2          Cardiff             Fulham          0.93000           1.71000
# 3  Manchester City            Burnley          2.81125           0.50000
# 4        Newcastle           Brighton          0.74750           1.60750
# 5         West Ham          Tottenham          1.09125           1.66500
# 6           Wolves            Watford              NaN               NaN
# 7     Huddersfield          Liverpool          0.59375           1.65750
# 8          Everton     Crystal Palace          1.19000           1.22000
# 9          Arsenal          Leicester          1.30125           1.36875
#
#    xG_pg_away_team  xGA_pg_away_team  xG_adjusted_home_team  \
# 0          1.60375           1.37250               1.958134
# 1          1.32625           1.75250               2.557535
# 2          1.17625           2.25000               1.519263
# 3          0.96125           1.76375               3.600012
# 4          1.18625           1.83875               0.997933
# 5          1.84875           1.20750               0.956707
# 6          1.31875           1.37625                    NaN
# 7          2.08250           0.73750               0.317931
# 8          0.87750           1.44500               1.248482
# 9          1.14250           1.07250               1.013271
#
#    xG_adjusted_away_team
# 0               1.250280
# 1               1.113383
# 2               1.460371
# 3               0.348959
# 4               1.384506
# 5               2.234909
# 6                    NaN
# 7               2.506144
# 8               0.777275
# 9               1.135397

# %%
#Accont for home adv
matchups['xG_adjusted_home_team'] = matchups['xG_adjusted_home_team'] * 1.2
matchups['xG_adjusted_away_team'] = matchups['xG_adjusted_away_team'] * 0.85
matchups
# Out:
#          Home_Team          Away_Team  xG_pg_home_team  xGA_pg_home_team  \
# 0          Chelsea  Manchester United          1.96500           1.07375
# 1      Bournemouth        Southampton          2.01000           1.15625
# 2          Cardiff             Fulham          0.93000           1.71000
# 3  Manchester City            Burnley          2.81125           0.50000
# 4        Newcastle           Brighton          0.74750           1.60750
# 5         West Ham          Tottenham          1.09125           1.66500
# 6           Wolves            Watford              NaN               NaN
# 7     Huddersfield          Liverpool          0.59375           1.65750
# 8          Everton     Crystal Palace          1.19000           1.22000
# 9          Arsenal          Leicester          1.30125           1.36875
#
#    xG_pg_away_team  xGA_pg_away_team  xG_adjusted_home_team  \
# 0          1.60375           1.37250               2.584737
# 1          1.32625           1.75250               3.375946
# 2          1.17625           2.25000               2.005427
# 3          0.96125           1.76375               4.752016
# 4          1.18625           1.83875               1.317272
# 5          1.84875           1.20750               1.262853
# 6          1.31875           1.37625                    NaN
# 7          2.08250           0.73750               0.419669
# 8          0.87750           1.44500               1.647996
# 9          1.14250           1.07250               1.337518
#
#    xG_adjusted_away_team
# 0               0.924582
# 1               0.823347
# 2               1.079944
# 3               0.258055
# 4               1.023842
# 5               1.652716
# 6                    NaN
# 7               1.853294
# 8               0.574795
# 9               0.839626

# %%
bookies = pd.read_csv('~/Desktop/python/python/xG/epl_week_9_implied_goals.csv')

matchups = pd.merge(matchups, bookies)

matchups['home_goals_diff'] = matchups['xG_adjusted_home_team'] - matchups['Bookies_Home_Goals']
matchups['away_goals_diff'] = matchups['xG_adjusted_away_team'] - matchups['Bookies_Away_Goals']

from matplotlib import pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
sns.set_color_codes('muted')

f, (ax1, ax2) = plt.subplots(nrows=2, figsize=(7, 10), sharex=True)

sns.barplot(x='home_goals_diff', y='Home_Team', data=matchups, color='b', ax=ax1)
sns.barplot(x='away_goals_diff', y='Away_Team', data=matchups, color='b', ax=ax2)

ax1.set(xlabel='', ylabel='', title='Home Teams')
ax2.set(xlabel='Difference in bookies implied goals vs our projected goals', ylabel='', title='Away Teams')

sns.despine(left=True, bottom=True)

# %%
import numpy as np

def win_cs(df, home_goals_col, away_goals_col, n=10000):
    home_win_list = []
    away_win_list = []
    home_cs_list = []
    away_cs_list = []
    for i in range(len(df)):
        avg_home_goals = df.iloc[i][home_goals_col]
        avg_away_goals = df.iloc[i][away_goals_col]

        home_goals_sim = np.random.poisson(avg_home_goals, n)
        away_goals_sim = np.random.poisson(avg_away_goals, n)

        sim = pd.DataFrame({'home_score': home_goals_sim, 'away_score': away_goals_sim})

        sim['home_win'] = np.where(sim['home_score'] > sim['away_score'], 1, 0)
        sim['away_win'] = np.where(sim['away_score'] > sim['home_score'], 1, 0)
        sim['home_clean_sheet'] = np.where(sim['away_score'] == 0, 1, 0)
        sim['away_clean_sheet'] = np.where(sim['home_score'] == 0, 1, 0)
        
        home_win_list.append(sim['home_win'].sum() / n)
        away_win_list.append(sim['away_win'].sum() / n)
        home_cs_list.append(sim['home_clean_sheet'].sum() / n)
        away_cs_list.append(sim['away_clean_sheet'].sum() / n)

    df['home_win'] = np.asarray(home_win_list)
    df['away_win'] = np.asarray(away_win_list)

    df['home_clean_sheet'] = np.asarray(home_cs_list)
    df['away_clean_sheet'] = np.asarray(away_cs_list)
    
    return df

matchups = win_cs(df=matchups, home_goals_col='xG_adjusted_home_team', away_goals_col='xG_adjusted_away_team')

displaycols = ['Home_Team', 'xG_adjusted_home_team', 'home_win', 'home_clean_sheet',
               'Away_Team', 'xG_adjusted_away_team', 'away_win', 'away_clean_sheet']
matchups[displaycols]
# Out:
#          Home_Team  xG_adjusted_home_team  home_win  home_clean_sheet  \
# 0          Chelsea               2.584737    0.7316            0.4017
# 1      Bournemouth               3.375946    0.8592            0.4477
# 2          Cardiff               2.005427    0.5917            0.3424
# 3  Manchester City               4.752016    0.9774            0.7775
# 4        Newcastle               1.317272    0.4339            0.3529
# 5         West Ham               1.262853    0.2929            0.1919
# 6     Huddersfield               0.419669    0.0742            0.1605
# 7          Everton               1.647996    0.6374            0.5594
# 8          Arsenal               1.337518    0.4822            0.4306
#
#            Away_Team  xG_adjusted_away_team  away_win  away_clean_sheet
# 0  Manchester United               0.924582    0.1117            0.0720
# 1        Southampton               0.823347    0.0525            0.0324
# 2             Fulham               1.079944    0.1944            0.1326
# 3            Burnley               0.258055    0.0041            0.0101
# 4           Brighton               1.023842    0.2905            0.2664
# 5          Tottenham               1.652716    0.4621            0.2810
# 6          Liverpool               1.853294    0.7144            0.6477
# 7     Crystal Palace               0.574795    0.1248            0.1891
# 8          Leicester               0.839626    0.2354            0.2609
